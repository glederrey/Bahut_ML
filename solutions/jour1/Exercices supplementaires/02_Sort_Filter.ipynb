# %% [markdown]
# # Chipotle
#
# Regardez le [Tutoriel Vidéo des Exercices Chipotle](https://youtu.be/ZZPiWZpdekA) pour voir un data scientist résoudre les exercices.

# %% [markdown]
# Cette fois, nous allons récupérer des données directement depuis Internet.
# Un grand merci à : https://github.com/justmarkham pour avoir partagé le jeu de données et les supports.
#
# ### Étape 1. Importez les bibliothèques nécessaires

# %%
import pandas as pd

# %% [markdown]
# ### Étape 2. Importez le jeu de données depuis cette [adresse](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Étape 3. Assignez-le à une variable appelée chipo.

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

chipo = pd.read_csv(url, sep = '\t')

# %% [markdown]
# ### Étape 4. Combien de produits coûtent plus de 10 $ ?

# %%
# nettoyez la colonne item_price et transformez-la en float
prices = [float(value[1 : -1]) for value in chipo.item_price]

# réassignez la colonne avec les prix nettoyés
chipo.item_price = prices

# supprimez les doublons dans item_name et quantity
chipo_filtered = chipo.drop_duplicates(['item_name','quantity','choice_description'])

# chipo_filtered

# sélectionnez uniquement les produits avec une quantité égale à 1
chipo_one_prod = chipo_filtered[chipo_filtered.quantity == 1]
chipo_one_prod

chipo_plus_10 = chipo_one_prod[chipo_one_prod['item_price'] > 10]

print(f"Il y a {len(chipo_plus_10)} produits qui coûtent plus de 10 $")

# %% [markdown]
# ### Étape 5. Quel est le prix de chaque article ?
# ###### affichez un DataFrame avec seulement deux colonnes : item_name et item_price

# %%
# supprimez les doublons dans item_name et quantity
# chipo_filtered = chipo.drop_duplicates(['item_name','quantity'])
chipo[(chipo['item_name'] == 'Chicken Bowl') & (chipo['quantity'] == 1)]

# sélectionnez uniquement les produits avec une quantité égale à 1
# chipo_one_prod = chipo_filtered[chipo_filtered.quantity == 1]

# sélectionnez uniquement les colonnes item_name et item_price
# price_per_item = chipo_one_prod[['item_name', 'item_price']]

# triez les valeurs du plus cher au moins cher
# price_per_item.sort_values(by = "item_price", ascending = False).head(20)

# %% [markdown]
# ### Étape 6. Triez par nom d'article

# %%
chipo.item_name.sort_values()

# OU

chipo.sort_values(by = "item_name")

# %% [markdown]
# ### Étape 7. Quelle était la quantité de l'article le plus cher commandé ?

# %%
chipo.sort_values(by = "item_price", ascending = False).head(1)

# %% [markdown]
# ### Étape 8. Combien de fois une Veggie Salad Bowl a-t-elle été commandée ?

# %%
chipo_salad = chipo[chipo.item_name == "Veggie Salad Bowl"]

len(chipo_salad)

# %% [markdown]
# ### Étape 9. Combien de fois quelqu'un a-t-il commandé plus d'un Canned Soda ?

# %%
chipo_drink_steak_bowl = chipo[(chipo.item_name == "Canned Soda") & (chipo.quantity > 1)]
len(chipo_drink_steak_bowl)
