# %% [markdown]
# # Chipotle
#
# Regardez le [Tutoriel Vidéo des Exercices Chipotle](https://www.youtube.com/watch?v=lpuYZ5EUyS8&list=PLgJhDSE2ZLxaY_DigHeiIDC1cD09rXgJv&index=2) pour voir un data scientist résoudre les exercices.

# %% [markdown]
# Cette fois, nous allons récupérer des données directement depuis Internet.
# Un grand merci à : https://github.com/justmarkham pour avoir partagé le jeu de données et les supports.
#
# ### Étape 1. Importez les bibliothèques nécessaires

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Étape 2. Importez le jeu de données depuis cette [adresse](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Étape 3. Assignez-le à une variable appelée chipo.

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
    
chipo = pd.read_csv(url, sep = '\t')

# %% [markdown]
# ### Étape 4. Affichez les 10 premières entrées

# %%
chipo.head(10)

# %% [markdown]
# ### Étape 5. Quel est le nombre d'observations dans le jeu de données ?

# %%
# Solution 1

chipo.shape[0]  # entrées <= 4622 observations

# %%
# Solution 2

chipo.info() # entrées <= 4622 observations

# %% [markdown]
# ### Étape 6. Quel est le nombre de colonnes dans le jeu de données ?

# %%
chipo.shape[1]

# %% [markdown]
# ### Étape 7. Affichez le nom de toutes les colonnes.

# %%
chipo.columns

# %% [markdown]
# ### Étape 8. Comment le jeu de données est-il indexé ?

# %%
chipo.index

# %% [markdown]
# ### Étape 9. Quel est l'article le plus commandé ?

# %%
c = chipo.groupby('item_name')
c = c.sum()
c = c.sort_values(['quantity'], ascending=False)
c.head(1)

# %% [markdown]
# ### Étape 10. Pour l'article le plus commandé, combien d'articles ont été commandés ?

# %%
c = chipo.groupby('item_name')
c = c.sum()
c = c.sort_values(['quantity'], ascending=False)
c.head(1)

# %% [markdown]
# ### Étape 11. Quel a été l'article le plus commandé dans la colonne choice_description ?

# %%
c = chipo.groupby('choice_description').sum()
c = c.sort_values(['quantity'], ascending=False)
c.head(1)
# Diet Coke 159

# %% [markdown]
# ### Étape 12. Combien d'articles ont été commandés au total ?

# %%
total_items_orders = chipo.quantity.sum()
total_items_orders

# %% [markdown]
# ### Étape 13. Transformez le prix des articles en float

# %% [markdown]
# #### Étape 13.a. Vérifiez le type de prix des articles

# %%
chipo.item_price.dtype

# %% [markdown]
# #### Étape 13.b. Créez une fonction lambda et changez le type de prix des articles

# %%
dollarizer = lambda x: float(x[1:-1])
chipo.item_price = chipo.item_price.apply(dollarizer)

# %% [markdown]
# #### Étape 13.c. Vérifiez le type de prix des articles

# %%
chipo.item_price.dtype

# %% [markdown]
# ### Étape 14. Quel a été le revenu pour la période du jeu de données ?

# %%
revenue = (chipo['quantity']* chipo['item_price']).sum()

print('Le revenu était de : $' + str(np.round(revenue,2)))

# %% [markdown]
# ### Étape 15. Combien de commandes ont été passées pendant la période ?

# %%
orders = chipo.order_id.value_counts().count()
orders

# %% [markdown]
# ### Étape 16. Quel est le revenu moyen par commande ?

# %%
# Solution 1

chipo['revenue'] = chipo['quantity'] * chipo['item_price']
order_grouped = chipo.groupby(by=['order_id']).sum()
order_grouped['revenue'].mean()

# %%
# Solution 2

chipo.groupby(by=['order_id'])['revenue'].sum().mean()

# %% [markdown]
# ### Étape 17. Combien d'articles différents sont vendus ?

# %%
chipo.item_name.value_counts().count()
