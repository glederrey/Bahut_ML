# %% [markdown]
# # Consommation d'Alcool des Étudiants

# %% [markdown]
# ### Introduction:
#
# Cette fois, vous allez télécharger un jeu de données depuis l'UCI.
#
# ### Étape 1. Importer les bibliothèques nécessaires

# %% [markdown]
# ### Étape 2. Importer le jeu de données à partir de cette [adresse](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv).

# %% [markdown]
# ### Étape 3. Assignez-le à une variable appelée df.

# %% [markdown]
# ### Étape 4. Pour les besoins de cet exercice, découpez le dataframe de la colonne 'school' jusqu'à la colonne 'guardian'

# %% [markdown]
# ### Étape 5. Créez une fonction lambda qui mettra en majuscule les chaînes de caractères.

# %% [markdown]
# ### Étape 6. Mettez en majuscule à la fois Mjob et Fjob

# %% [markdown]
# ### Étape 7. Affichez les derniers éléments du jeu de données.

# %% [markdown]
# ### Étape 8. Avez-vous remarqué que le dataframe original est toujours en minuscules ? Pourquoi est-ce le cas ? Corrigez-le et mettez en majuscule Mjob et Fjob.

# %% [markdown]
# ### Étape 9. Créez une fonction appelée majority qui renvoie une valeur booléenne à une nouvelle colonne appelée legal_drinker (Considérez la majorité comme étant plus de 17 ans)

# %% [markdown]
# ### Étape 10. Multipliez chaque nombre du jeu de données par 10.
# ##### Je sais que cela n'a pas de sens, n'oubliez pas que c'est juste un exercice
