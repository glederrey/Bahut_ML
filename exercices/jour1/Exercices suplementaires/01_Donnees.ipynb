# %% [markdown]
# # Chipotle

# %% [markdown]
# Cette fois, nous allons extraire des données directement d'Internet.
# Remerciements spéciaux à : https://github.com/justmarkham pour le partage du jeu de données et des matériaux.
#
# ### Étape 1. Importez les bibliothèques nécessaires

# %% [markdown]
# ### Étape 2. Importez le jeu de données à partir de cette [adresse](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Étape 3. Assignez-le à une variable appelée chipo.

# %% [markdown]
# ### Étape 4. Affichez les 10 premières entrées

# %% [markdown]
# ### Étape 5. Quel est le nombre d'observations dans le jeu de données ?

# %%
# Solution 1

# %%
# Solution 2

# %% [markdown]
# ### Étape 6. Quel est le nombre de colonnes dans le jeu de données ?

# %% [markdown]
# ### Étape 7. Affichez le nom de toutes les colonnes.

# %% [markdown]
# ### Étape 8. Comment est indexé le jeu de données ?

# %% [markdown]
# ### Étape 9. Quel était l'article le plus commandé ?

# %% [markdown]
# ### Étape 10. Pour l'article le plus commandé, combien d'articles ont été commandés ?

# %% [markdown]
# ### Étape 11. Quel était l'article le plus commandé dans la colonne choice_description ?

# %% [markdown]
# ### Étape 12. Combien d'articles ont été commandés au total ?

# %% [markdown]
# ### Étape 13. Convertissez le prix de l'article en float

# %% [markdown]
# #### Étape 13.a. Vérifiez le type du prix de l'article

# %% [markdown]
# #### Étape 13.b. Créez une fonction lambda et changez le type du prix de l'article

# %% [markdown]
# #### Étape 13.c. Vérifiez le type du prix de l'article

# %% [markdown]
# ### Étape 14. Quel était le chiffre d'affaires pour la période dans le jeu de données ?

# %% [markdown]
# ### Étape 15. Combien de commandes ont été passées pendant la période ?

# %% [markdown]
# ### Étape 16. Quel est le montant moyen du chiffre d'affaires par commande ?

# %%
# Solution 1

# %%
# Solution 2

# %% [markdown]
# ### Étape 17. Combien d'articles différents sont vendus ?
