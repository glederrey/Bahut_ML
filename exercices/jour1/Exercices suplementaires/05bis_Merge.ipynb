# %% [markdown]
# # Noms Fictifs

# %% [markdown]
# ### Introduction:
#
# Cette fois, vous allez créer à nouveau des données
#
# Remerciements spéciaux à [Chris Albon](http://chrisalbon.com/) pour le partage du jeu de données et des matériaux.
# Tous les crédits de cet exercice lui appartiennent.
#
# Pour comprendre de quoi il s'agit, allez [ici](https://blog.codinghorror.com/a-visual-explanation-of-sql-joins/).
#
# ### Étape 1. Importer les bibliothèques nécessaires

# %% [markdown]
# ### Étape 2. Créer les 3 DataFrames basés sur les données brutes suivantes

# %%
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %% [markdown]
# ### Étape 3. Assignez chacun à une variable appelée data1, data2, data3

# %% [markdown]
# ### Étape 4. Joignez les deux dataframes le long des lignes et assignez à all_data

# %% [markdown]
# ### Étape 5. Joignez les deux dataframes le long des colonnes et assignez à all_data_col

# %% [markdown]
# ### Étape 6. Affichez data3

# %% [markdown]
# ### Étape 7. Fusionnez all_data et data3 selon la valeur subject_id

# %% [markdown]
# ### Étape 8. Fusionnez uniquement les données qui ont le même 'subject_id' dans data1 et data2

# %% [markdown]
# ### Étape 9. Fusionnez toutes les valeurs de data1 et data2, avec les enregistrements correspondants des deux côtés lorsqu'ils sont disponibles.
