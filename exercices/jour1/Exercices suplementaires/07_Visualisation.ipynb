# %% [markdown]
# # Chipotle

# %% [markdown]
# Cette fois, nous allons récupérer les données directement depuis Internet.
# Un grand merci à : https://github.com/justmarkham pour avoir partagé le jeu de données et les supports.
#
# ### Étape 1. Importez les bibliothèques nécessaires

# %% [markdown]
# ### Étape 2. Importez le jeu de données depuis cette [adresse](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Étape 3. Assignez-le à une variable appelée chipo.

# %% [markdown]
# ### Étape 4. Affichez les 10 premières entrées

# %% [markdown]
# ### Étape 5. Créez un histogramme des 5 articles les plus achetés

# %% [markdown]
# ### Étape 6. Créez un nuage de points avec le nombre d'articles commandés par prix de commande
# #### Indice : Le prix doit être sur l'axe X et les articles commandés sur l'axe Y

# %% [markdown]
# ### Étape 7. BONUS : Créez une question et un graphique pour répondre à votre propre question.
