# %% [markdown]
# # Consommation d'Alcool des Étudiants

# %% [markdown]
# ### Introduction:
#
# GroupBy peut être résumé comme Diviser-Appliquer-Combiner.
#
# Remerciements spéciaux à: https://github.com/justmarkham pour le partage du jeu de données et des matériaux.
#
# Consultez ce [Diagramme](http://i.imgur.com/yjNkiwL.png)
# ### Étape 1. Importer les bibliothèques nécessaires

# %% [markdown]
# ### Étape 2. Importer le jeu de données à partir de cette [adresse](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Étape 3. Assignez-le à une variable appelée drinks.

# %% [markdown]
# ### Étape 4. Quel continent consomme plus de bière en moyenne?

# %% [markdown]
# ### Étape 5. Pour chaque continent, affichez les statistiques de consommation de vin.

# %% [markdown]
# ### Étape 6. Affichez la consommation moyenne d'alcool par continent pour chaque colonne

# %% [markdown]
# ### Étape 7. Affichez la consommation médiane d'alcool par continent pour chaque colonne

# %% [markdown]
# ### Étape 8. Affichez les valeurs moyenne, minimale et maximale pour la consommation de spiritueux.
# #### Cette fois, produisez un DataFrame
