# %% [markdown]
# # Statistiques de Vent

# %% [markdown]
# ### Introduction:
#
# Les données ont été modifiées pour contenir certaines valeurs manquantes, identifiées par NaN.
# L'utilisation de pandas devrait faciliter cet exercice,
# en particulier pour la question bonus.
#
# Vous devriez être capable d'effectuer toutes ces opérations sans utiliser
# de boucle for ou d'autre construction de boucle.
#
#
# 1. Les données dans 'wind.data' ont le format suivant:

# %%
"""
Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
"""

# %% [markdown]
#    Les trois premières colonnes sont l'année, le mois et le jour. Les
#    12 colonnes restantes sont les vitesses moyennes du vent en nœuds à 12
#    endroits en Irlande ce jour-là.
#
#    Plus d'informations sur le jeu de données [ici](wind.desc).

# %% [markdown]
# ### Étape 1. Importer les bibliothèques nécessaires

# %% [markdown]
# ### Étape 2. Importer le jeu de données à partir de cette [adresse](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data)

# %% [markdown]
# ### Étape 3. Assignez-le à une variable appelée data et remplacez les 3 premières colonnes par un index datetime approprié.

# %% [markdown]
# ### Étape 4. Année 2061 ? Avons-nous vraiment des données de cette année ? Créez une fonction pour corriger cela et appliquez-la.

# %% [markdown]
# ### Étape 5. Définissez les bonnes dates comme index. Faites attention au type de données, il devrait être datetime64[ns].

# %% [markdown]
# ### Étape 6. Calculez combien de valeurs sont manquantes pour chaque emplacement sur l'ensemble des enregistrements.
# #### Elles doivent être ignorées dans tous les calculs ci-dessous.

# %% [markdown]
# ### Étape 7. Calculez combien de valeurs non manquantes il y a au total.

# %% [markdown]
# ### Étape 8. Calculez les vitesses moyennes du vent sur tous les emplacements et toutes les périodes.
# #### Un seul nombre pour l'ensemble du jeu de données.

# %% [markdown]
# ### Étape 9. Créez un DataFrame appelé loc_stats et calculez les vitesses de vent minimales, maximales et moyennes ainsi que les écarts-types des vitesses de vent à chaque emplacement sur tous les jours
#
# #### Un ensemble différent de nombres pour chaque emplacement.

# %% [markdown]
# ### Étape 10. Créez un DataFrame appelé day_stats et calculez les vitesses de vent minimales, maximales et moyennes ainsi que les écarts-types des vitesses de vent sur tous les emplacements pour chaque jour.
#
# #### Un ensemble différent de nombres pour chaque jour.

# %% [markdown]
# ### Étape 11. Trouvez la vitesse moyenne du vent en janvier pour chaque emplacement.
# #### Traitez janvier 1961 et janvier 1962 tous deux comme janvier.

# %% [markdown]
# ### Étape 12. Réduisez l'échantillonnage de l'enregistrement à une fréquence annuelle pour chaque emplacement.

# %% [markdown]
# ### Étape 13. Réduisez l'échantillonnage de l'enregistrement à une fréquence mensuelle pour chaque emplacement.

# %% [markdown]
# ### Étape 14. Réduisez l'échantillonnage de l'enregistrement à une fréquence hebdomadaire pour chaque emplacement.

# %% [markdown]
# ### Étape 15. Calculez les vitesses de vent minimales, maximales et moyennes ainsi que les écarts-types des vitesses de vent sur tous les emplacements pour chaque semaine (supposez que la première semaine commence le 2 janvier 1961) pour les 52 premières semaines.
