# %% [markdown]
# # Pourboires

# %% [markdown]
# ### Introduction:
#
# Cet exercice a été créé sur la base du tutoriel et de la documentation de [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# Le jeu de données utilisé est tips (pourboires) de Seaborn.
#
# ### Étape 1. Importer les bibliothèques nécessaires:

# %% [markdown]
# ### Étape 2. Importer le jeu de données à partir de cette [adresse](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Étape 3. Assignez-le à une variable appelée tips

# %% [markdown]
# ### Étape 4. Supprimez la colonne Unnamed 0

# %% [markdown]
# ### Étape 5. Tracez l'histogramme de la colonne total_bill

# %% [markdown]
# ### Étape 6. Créez un nuage de points présentant la relation entre total_bill et tip

# %% [markdown]
# ### Étape 7. Créez une image avec la relation entre total_bill, tip et size.

# %% [markdown]
# ### Étape 8. Présentez la relation entre les jours et la valeur total_bill

# %% [markdown]
# ### Étape 9. Créez un nuage de points avec le jour comme axe y et le pourboire comme axe x, différenciez les points par sexe

# %% [markdown]
# ### Étape 10. Créez un box plot présentant le total_bill par jour en différenciant le moment (Dîner ou Déjeuner)

# %% [markdown]
# ### Étape 11. Créez deux histogrammes de la valeur du pourboire pour le Dîner et le Déjeuner. Ils doivent être côte à côte.

# %% [markdown]
# ### Étape 12. Créez deux graphiques de nuages de points, un pour les Hommes et un autre pour les Femmes, présentant la relation entre la valeur total_bill et le pourboire, en différenciant par fumeur ou non-fumeur
# ### Ils doivent être côte à côte.

# %% [markdown]
# ### BONUS : Créez votre propre question et répondez-y à l'aide d'un graphique.
