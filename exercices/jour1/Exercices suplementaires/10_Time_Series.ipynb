# %% [markdown]
# # Action Apple

# %% [markdown]
# ### Introduction :
#
# Nous allons utiliser le prix de l'action Apple.
#
#
# ### Étape 1. Importez les bibliothèques nécessaires

# %% [markdown]
# ### Étape 2. Importez le jeu de données depuis cette [adresse](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv)

# %% [markdown]
# ### Étape 3. Assignez-le à une variable appelée apple

# %% [markdown]
# ### Étape 4. Vérifiez le type des colonnes

# %% [markdown]
# ### Étape 5. Transformez la colonne Date en type datetime

# %% [markdown]
# ### Étape 6. Définissez la date comme index

# %% [markdown]
# ### Étape 7. Y a-t-il des dates en double ?

# %% [markdown]
# ### Étape 8. Oups... il semble que l'index commence par la date la plus récente. Faites en sorte que la première entrée soit la date la plus ancienne.

# %% [markdown]
# ### Étape 9. Obtenez le dernier jour ouvrable de chaque mois

# %% [markdown]
# ### Étape 10. Quelle est la différence en jours entre le premier jour et le plus ancien ?

# %% [markdown]
# ### Étape 11. Combien de mois avons-nous dans les données ?

# %% [markdown]
# ### Étape 12. Tracez la valeur 'Adj Close'. Définissez la taille de la figure à 13,5 x 9 pouces

# %% [markdown]
# ### BONUS : Créez votre propre question et répondez-y.
