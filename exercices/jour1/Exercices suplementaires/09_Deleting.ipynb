# %% [markdown]
# # Vin

# %% [markdown]
# ### Introduction :
#
# Cet exercice est une adaptation du jeu de données UCI Wine.
# Le seul objectif est de pratiquer la suppression de données avec pandas.
#
# ### Étape 1. Importez les bibliothèques nécessaires

# %% [markdown]
# ### Étape 2. Importez le jeu de données depuis cette [adresse](https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data).

# %% [markdown]
# ### Étape 3. Assignez-le à une variable appelée vin

# %% [markdown]
# ### Étape 4. Supprimez les colonnes première, quatrième, septième, neuvième, onzième, treizième et quatorzième

# %% [markdown]
# ### Étape 5. Assignez les colonnes comme suit :
#
# Les attributs sont (donnés par Riccardo Leardi, riclea '@' anchem.unige.it) :
# 1) alcool
# 2) acide_malique
# 3) alcalinité_de_la_cendre
# 4) magnésium
# 5) flavonoïdes
# 6) proanthocyanidines
# 7) teinte

# %% [markdown]
# ### Étape 6. Remplacez les valeurs des 3 premières lignes de la colonne alcool par NaN

# %% [markdown]
# ### Étape 7. Maintenant, remplacez les valeurs des lignes 3 et 4 de la colonne magnésium par NaN

# %% [markdown]
# ### Étape 8. Remplissez les valeurs NaN avec le nombre 10 dans la colonne alcool et 100 dans la colonne magnésium

# %% [markdown]
# ### Étape 9. Comptez le nombre de valeurs manquantes

# %% [markdown]
# ### Étape 10. Créez un tableau de 10 nombres aléatoires jusqu'à 10

# %% [markdown]
# ### Étape 11. Utilisez les nombres aléatoires générés comme index et assignez une valeur NaN à chaque cellule correspondante.

# %% [markdown]
# ### Étape 12. Combien de valeurs manquantes avons-nous ?

# %% [markdown]
# ### Étape 13. Supprimez les lignes contenant des valeurs manquantes

# %% [markdown]
# ### Étape 14. Affichez uniquement les valeurs non nulles de la colonne alcool

# %% [markdown]
# ### Étape 15. Réinitialisez l'index pour qu'il commence à 0

# %% [markdown]
# ### BONUS : Créez votre propre question et répondez-y.
