# %% [markdown]
# # Voitures MPG

# %% [markdown]
# ### Introduction:
#
# L'exercice suivant utilise des données du [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Étape 1. Importer les bibliothèques nécessaires

# %% [markdown]
# ### Étape 2. Importer le premier jeu de données [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv) et [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv).

# %% [markdown]
#    ### Étape 3. Assignez chacun à une variable appelée cars1 et cars2

# %% [markdown]
# ### Étape 4. Oups, il semble que notre premier jeu de données contienne des colonnes vides sans nom, corrigez cars1

# %% [markdown]
# ### Étape 5. Quel est le nombre d'observations dans chaque jeu de données ?

# %% [markdown]
# ### Étape 6. Joignez cars1 et cars2 en un seul DataFrame appelé cars

# %% [markdown]
# ### Étape 7. Oups, il manque une colonne, appelée owners. Créez une série de nombres aléatoires de 15 000 à 73 000.

# %% [markdown]
# ### Étape 8. Ajoutez la colonne owners à cars
