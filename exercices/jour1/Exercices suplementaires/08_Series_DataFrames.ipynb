# %% [markdown]
# # Pokémon

# %% [markdown]
# ### Introduction :
#
# Cette fois, vous allez créer les données.
#
#
#
# ### Étape 1. Importez les bibliothèques nécessaires

# %% [markdown]
# ### Étape 2. Créez un dictionnaire de données qui ressemble au tableau ci-dessous
#
# | evolution  | hp | name       | pokedex | type    |
# |------------|----|-----------:|---------|---------|
# | Herbizarre | 45 | Bulbizarre | oui     | plante  |
# | Salamèche  | 39 | Reptincel  | non     | feu     |
# | Carabaffe  | 44 | Carapuce   | oui     | eau     |
# | Chrysacier | 45 | Chenipan   | non     | insecte |

# %% [markdown]
# ### Étape 3. Assignez-le à une variable appelée pokemon

# %% [markdown]
# ### Étape 4. Oups... il semble que les colonnes du DataFrame soient dans l'ordre alphabétique. Placez les colonnes dans l'ordre suivant : name, type, hp, evolution, pokedex

# %% [markdown]
# ### Étape 5. Ajoutez une autre colonne appelée place, et insérez ce que vous avez en tête.

# %% [markdown]
# ### Étape 6. Présentez le type de chaque colonne

# %% [markdown]
# ### BONUS : Créez votre propre question et répondez-y.
